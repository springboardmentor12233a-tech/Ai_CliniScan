# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/dasandco/clindataset/train_meta.csv
# /kaggle/input/datasets/dasandco/clindataset/train.csv
# /kaggle/input/datasets/dasandco/clindataset/test/b3f67ac077531f44dd06275af31edbd9.png
# /kaggle/input/datasets/dasandco/clindataset/test/e94fde220360e4b769921e16059cc6af.png
# /kaggle/input/datasets/dasandco/clindataset/test/d2993271d0a49d1d821db1174861629a.png
# /kaggle/input/datasets/dasandco/clindataset/test/99732e844196448b90e50973d6ba5224.png
# /kaggle/input/datasets/dasandco/clindataset/test/3c6f70f56258cad13d74e7f17da1c7c5.png
# /kaggle/input/datasets/dasandco/clindataset/test/5d6a25163584e7b05a528d3f94fda500.png
# /kaggle/input/datasets/dasandco/clindataset/test/435c653f95dd47326063ff145a0fa82e.png
# /kaggle/input/datasets/dasandco/clindataset/test/3020abca19e8fa4bba62fe583f07050d.png
# /kaggle/input/datasets/dasandco/clindataset/test/58d76e6dae9bbb3a24fe79f771b735a6.png
# /kaggle/input/datasets/dasandco/clindataset/test/204c690fdc9b400342f9b5a271523bfe.png
# /kaggle/input/datasets/dasandco/clindataset/test/89026693453e72d07cdccd6a98999fd5.png
# /kaggle/input/datasets/dasandco/clindataset/test/cc53f79260c8d490cbfbc3cd78fe8516.png
# /kaggle/input/datasets/dasandco/clindataset/test/03a2e400656f58841beb7f62584ee3e9.png
# /kaggle/input/datasets/dasandco/clindataset/test/a12c4d0713661192a6e0bbd0ed1b231e.png
# /kaggle/input/datasets/dasandco/clindataset/test/833c4ee4ef52adb663076af69efe3c22.png
# /kaggle/input/datasets/dasandco/clindataset/test/2f3821fa3729d0814a5dc4890261fa51.png
# /kaggle/input/datasets/dasandco/clindataset/test/7daad4dedca1737fe750c7ce8df6fa88.png
# /kaggle/input/datasets/dasandco/clindataset/test/b4c301c911e519f94d0e2752fa3e1a52.png
# /kaggle/input/datasets/dasandco/clindataset/test/0eca5bbff12b841c18d231fc8cda0eeb.png
# /kaggle/input/datasets/dasandco/clindataset/test/186398ac83152a0870a3c329646e66ae.png
# /kaggle/input/datasets/dasandco/clindataset/test/03f00327702f48c4b6726a0e1649a157.png
# /kaggle/input/datasets/dasandco/clindataset/test/bfae73fca53a1656750ea6499bd98167.png
# /kaggle/input/datasets/dasandco/clindataset/test/69f8a7c2bc453e0c3c71442dd0c46d91.png
# /kaggle/input/datasets/dasandco/clindataset/test/d0ce010fd5c4d7c2b3f0d00b16449b1a.png
# /kaggle/input/datasets/dasandco/clindataset/test/cee65cff7342c464d3eeeaa26bde0b7e.png
# /kaggle/input/datasets/dasandco/clindataset/test/ff5b2414a7b94c78bb0073e656eb9c0e.png
# /kaggle/input/datasets/dasandco/clindataset/test/f18f78dc60869c8b9e96393876669b9e.png
# /kaggle/input/datasets/dasandco/clindataset/test/71c27a4f0124bfee54339b40ee4164cc.png
# /kaggle/input/datasets/dasandco/clindataset/test/9021a7769e065e341d0893fac8250f2f.png
# /kaggle/input/datasets/dasandco/clindataset/test/887371388c9802ebf6e18d617d1c9ead.png
# /kaggle/input/datasets/dasandco/clindataset/test/d41d8830d84bbbbce9584a341d0bf2e5.png
# /kaggle/input/datasets/dasandco/clindataset/test/724c7003e9c18c07c5f925edd825ef02.png
# /kaggle/input/datasets/dasandco/clindataset/test/d3b0cb27deaf4744187429110a1ada88.png
# /kaggle/input/datasets/dasandco/clindataset/test/63a81da4e2cbd78bdf8eddbdc368b3fb.png
# /kaggle/input/datasets/dasandco/clindataset/test/f1e4ac8d6db9d986fbff411c6a314857.png
# /kaggle/input/datasets/dasandco/clindataset/test/2362bae8a9b107f454ce8bcb5dd80180.png
# /kaggle/input/datasets/dasandco/clindataset/test/163c884cba35d5d5ca50b7b8ea36a1fa.png
# /kaggle/input/datasets/dasandco/clindataset/test/2d2bf2587e5341d8e4ae9c24150efdd9.png
# /kaggle/input/datasets/dasandco/clindataset/test/766238ff8d88651dfb314bc9c70986f9.png
# /kaggle/input/datasets/dasandco/clindataset/test/a6967906c3e742137e65cd797236c01f.png
# /kaggle/input/datasets/dasandco/clindataset/test/367d407eeafceb8dd55ee11f7e52b3d7.png
# /kaggle/input/datasets/dasandco/clindataset/test/785140281117595d1818b8133d43d3bc.png
# /kaggle/input/datasets/dasandco/clindataset/test/e0cb6328956c1b3b7f70c970cb9dcca7.png
# /kaggle/input/datasets/dasandco/clindataset/test/3ffc3654b8342c68038a2249787f87e9.png
# /kaggle/input/datasets/dasandco/clindataset/test/bac58dc3a82b5a3d1f1affc2e9a5d6cf.png
# /kaggle/input/datasets/dasandco/clindataset/test/efaa3db93267375dcd48555debfaef9b.png
# /kaggle/input/datasets/dasandco/clindataset/test/c433a34f8cf9c7b894a9d52c80678b0e.png
# /kaggle/input/datasets/dasandco/clindataset/test/88b95ee8ca5cf416d2d4eefe6fdda544.png
# /kaggle/input/datasets/dasandco/clindataset/test/b83b3054e9691c9a180063acd5a3b8ea.png
# /kaggle/input/datasets/dasandco/clindataset/test/7befd6661fd921f67f8d9cb84f98868f.png
# /kaggle/input/datasets/dasandco/clindataset/test/c5862a6925bc6ecf894a73710cdf6b79.png
# /kaggle/input/datasets/dasandco/clindataset/test/ec73f422063ce59169c6c13d3c6227a7.png
# /kaggle/input/datasets/dasandco/clindataset/test/7882ac9a9fa79ddd245f540d6f6e4af5.png
# /kaggle/input/datasets/dasandco/clindataset/test/5df8ceb0c06c1a5a7eae66e68cecc804.png
# /kaggle/input/datasets/dasandco/clindataset/test/5a5981d693eb84fee6381d8e41a3e27d.png
# /kaggle/input/datasets/dasandco/clindataset/test/abe3e3c83a7dc58474450b601e20cffb.png
# /kaggle/input/datasets/dasandco/clindataset/test/4d60dedd8acc1fc0c83596e2a0c6d0df.png
# /kaggle/input/datasets/dasandco/clindataset/test/9af18fd0a3ba73f3340c69a5af4f3053.png
# /kaggle/input/datasets/dasandco/clindataset/test/69cab0314beaa8eefe2f3b4d316b2642.png
# /kaggle/input/datasets/dasandco/clindataset/test/282dc34d270eccc44a61901afbd4791d.png
# /kaggle/input/datasets/dasandco/clindataset/test/d154ed5ece3a6da5cadf6658a7076cc7.png
# /kaggle/input/datasets/dasandco/clindataset/test/0e2a6f637bc997be18ec30687bdc3762.png
# /kaggle/input/datasets/dasandco/clindataset/test/f2cee76e8d488de8de9a602b505cfe9d.png
# /kaggle/input/datasets/dasandco/clindataset/test/fb36e668ed268bf65084fe3d1ff7a21f.png
# /kaggle/input/datasets/dasandco/clindataset/test/2f977e3238400bf52f146ed0eb3a57c1.png
# /kaggle/input/datasets/dasandco/clindataset/test/4e7c01fd1cfbfc54d2ac4913f6359be7.png
# /kaggle/input/datasets/dasandco/clindataset/test/4b19ca098b479dd60cc2288ab680e3eb.png
# /kaggle/input/datasets/dasandco/clindataset/test/715f936a0ab2aca1f671041c7704e15f.png
# /kaggle/input/datasets/dasandco/clindataset/test/4b7e11251461edb6c46b6acb16583eb2.png
# /kaggle/input/datasets/dasandco/clindataset/test/9b4c819c56238d760d50d8ee8b4cea15.png
# /kaggle/input/datasets/dasandco/clindataset/test/08504fa0ea409654d6328e51de2fb3b9.png
# /kaggle/input/datasets/dasandco/clindataset/test/2f49fa57375e32c9d69f8205bd5b0a96.png
# /kaggle/input/datasets/dasandco/clindataset/test/f706b17da0996dc76d0ab344fd0b2ae0.png
# /kaggle/input/datasets/dasandco/clindataset/test/ba149dfb4f399902c41699b514d9fe39.png
# /kaggle/input/datasets/dasandco/clindataset/test/86d44d9e44347855ffc41410e213f3fc.png
# /kaggle/input/datasets/dasandco/clindataset/test/4112f6a0a3a7509212801f2b3132dfda.png
# /kaggle/input/datasets/dasandco/clindataset/test/68ea2c78d412b314ebe9b7261173f274.png
# /kaggle/input/datasets/dasandco/clindataset/test/0ed15ab15f2304a9a811d7fa6ce843de.png
# /kaggle/input/datasets/dasandco/clindataset/test/375230098adb78e73b6d162c9e30acd6.png
# /kaggle/input/datasets/dasandco/clindataset/test/e541711f560cd700d7fdddd1d3dd98d4.png
# /kaggle/input/datasets/dasandco/clindataset/test/a54dfc022eedd7f8ba392bc6dc243f5b.png
# /kaggle/input/datasets/dasandco/clindataset/test/dea1a3c3102b2b3efccffd9452c1da7f.png
# /kaggle/input/datasets/dasandco/clindataset/test/fe62409506fa9ca50424e85c378d30da.png
# /kaggle/input/datasets/dasandco/clindataset/test/667ee8460269a5864a0fc00b4a9bf62f.png
# /kaggle/input/datasets/dasandco/clindataset/test/97f0ad3b3ccbfc848bf9cc7e1a76377c.png
# /kaggle/input/datasets/dasandco/clindataset/test/66f8ea5f21b26731b6bd4a1574c25abb.png
# /kaggle/input/datasets/dasandco/clindataset/test/c377f3a25159c6cf5d48a346d522db65.png
# /kaggle/input/datasets/dasandco/clindataset/test/4bed68bcc1b764cd964f5e96ca83884c.png
# /kaggle/input/datasets/dasandco/clindataset/test/3873c2297c6f237f67defb7ef1243a3a.png
# /kaggle/input/datasets/dasandco/clindataset/test/2e65079841bd4b68a51facf322a72cb2.png
# /kaggle/input/datasets/dasandco/clindataset/test/0af8628f5cbe0786db483a10934d1be5.png
# /kaggle/input/datasets/dasandco/clindataset/test/e0451ee4428ed80d7e574361b44e0f57.png
# /kaggle/input/datasets/dasandco/clindataset/test/4f5fe9950e605a42d75ea7bfb8230866.png
# /kaggle/input/datasets/dasandco/clindataset/test/82cb7ac2b8ad46f2be437a640d6744f5.png
# /kaggle/input/datasets/dasandco/clindataset/test/84c632197eb00d0bf42931649cf26a84.png
# /kaggle/input/datasets/dasandco/clindataset/test/da48002e9656b3ae99cf7cad5fef4d33.png
# /kaggle/input/datasets/dasandco/clindataset/test/93cdc1245a32efee2b5ec92abe175e8b.png
# /kaggle/input/datasets/dasandco/clindataset/test/aab92c2f28c68c50ae92943aa4f00a13.png
# /kaggle/input/datasets/dasandco/clindataset/test/880b327f38330a6d6f8ecd18678ab1eb.png
# /kaggle/input/datasets/dasandco/clindataset/test/b62d8ad6e5876091e7ecfb170aacd533.png
# /kaggle/input/datasets/dasandco/clindataset/test/17eefd92847c5a56c84990047ab2d5ae.png
# /kaggle/input/datasets/dasandco/clindataset/test/07cdcea9a6c3049d7a02ade9c680d4d7.png
# /kaggle/input/datasets/dasandco/clindataset/test/9112756a7e8b3ae899c07ee78f42ba65.png
# /kaggle/input/datasets/dasandco/clindataset/test/25aec56a720623274a5d51c6faa764b4.png
# /kaggle/input/datasets/dasandco/clindataset/test/b49ae99734943af981150e563b4bf26f.png
# /kaggle/input/datasets/dasandco/clindataset/test/79c75c4aed44b844eca14be58a9deb9f.png
# /kaggle/input/datasets/dasandco/clindataset/test/6c4f50895f5342d5377b80c6dca50ac4.png
# /kaggle/input/datasets/dasandco/clindataset/test/9e8a5a85012b7b8c5dd164382d93e089.png
# /kaggle/input/datasets/dasandco/clindataset/test/3cdcf9e3f1b8d011d20f4c1c779851ee.png
# /kaggle/input/datasets/dasandco/clindataset/test/ec2176e084f94ee8f9fc662354262062.png
# /kaggle/input/datasets/dasandco/clindataset/test/12cea68e4b795e545877708c16b8dbdd.png
# /kaggle/input/datasets/dasandco/clindataset/test/529e1b84a553a1eace23e78a49d041aa.png
# /kaggle/input/datasets/dasandco/clindataset/test/6d2219f1c8c4af1e05acfe2c6e02f1d5.png
# /kaggle/input/datasets/dasandco/clindataset/test/e6959c57425deed1ffb111f627420f03.png
# /kaggle/input/datasets/dasandco/clindataset/test/739077a7a2add5c87ca97bda44c8bb95.png
# /kaggle/input/datasets/dasandco/clindataset/test/e9a39ad929072dc4faafe351d8264807.png
# /kaggle/input/datasets/dasandco/clindataset/test/833920cee0073b2295b713e8e99a1183.png
# /kaggle/input/datasets/dasandco/clindataset/test/a868475eb59e09a1fc9d6d5c12511d43.png
# /kaggle/input/datasets/dasandco/clindataset/test/1c0edcab874f51772ec86ac6405a0a69.png
# /kaggle/input/datasets/dasandco/clindataset/test/05a7460866e0d128b5db471431675483.png
# /kaggle/input/datasets/dasandco/clindataset/test/edc89e6e9572acea901d5d41c970dd3d.png
# /kaggle/input/datasets/dasandco/clindataset/test/3e86f7a0078799279f334db4074f109e.png
# /kaggle/input/datasets/dasandco/clindataset/test/6490e2cf8ea994ef53c06c287d59085d.png
# /kaggle/input/datasets/dasandco/clindataset/test/1ddd49f2867bac4430aaad6d35445a61.png
# /kaggle/input/datasets/dasandco/clindataset/test/10fc9d37a7f2808a1c41da80d81a291f.png
# /kaggle/input/datasets/dasandco/clindataset/test/bb80a296415463575853956be0fed4f4.png
# /kaggle/input/datasets/dasandco/clindataset/test/706814b8f626ce46d5614029ec51dc44.png
# /kaggle/input/datasets/dasandco/clindataset/test/a06ad52f2d2ee79591f6381b9e1c19c3.png
# /kaggle/input/datasets/dasandco/clindataset/test/dce261d70de131c9bad1229edcca61bf.png
# /kaggle/input/datasets/dasandco/clindataset/test/940635db4ae037a40c8a95a81de062d6.png
# /kaggle/input/datasets/dasandco/clindataset/test/fc4c2d3ed1870a845a6aafc7112878df.png
# /kaggle/input/datasets/dasandco/clindataset/test/e91fa68e2ba762b434a9fc7571ccdd3d.png
# /kaggle/input/datasets/dasandco/clindataset/test/91666dfbe7cae907ee17c02084290e4b.png
# /kaggle/input/datasets/dasandco/clindataset/test/969570a649d3d7f430dd2e4ec11b7bc4.png
# /kaggle/input/datasets/dasandco/clindataset/test/99f4f493e0ed0a3cd70fe397736534e4.png
# /kaggle/input/datasets/dasandco/clindataset/test/c3f6c25774cd7a6190ce10f919087585.png
# /kaggle/input/datasets/dasandco/clindataset/test/a651f4b5a5f723845a76084017650322.png
# /kaggle/input/datasets/dasandco/clindataset/test/5c22ee484c55a079ac153153368ecd60.png
# /kaggle/input/datasets/dasandco/clindataset/test/1db20acd44b0e120b91f137a46da1ff6.png
# /kaggle/input/datasets/dasandco/clindataset/test/c52f84d7c7c66721ab0d01c181361fa5.png
# /kaggle/input/datasets/dasandco/clindataset/test/c8fcdb8ff1a58c1c12d411271b003e3b.png
# /kaggle/input/datasets/dasandco/clindataset/test/3fb7243f97d1493015a5f3cb880d8e4a.png
# /kaggle/input/datasets/dasandco/clindataset/test/56df1818b6567b2e812e615365b22e60.png
# /kaggle/input/datasets/dasandco/clindataset/test/01eb30a37b6f5fed8a8d3ab2d1c0a7d6.png
# /kaggle/input/datasets/dasandco/clindataset/test/7bca1be5f1f3c14c49be003896da9b27.png
# /kaggle/input/datasets/dasandco/clindataset/test/a3196674db73c50c7450c8964370e783.png
# /kaggle/input/datasets/dasandco/clindataset/test/7a9a75ad8f406d7561aa2f0ef7000933.png
# /kaggle/input/datasets/dasandco/clindataset/test/ae7fa77d4ac17896070888e1e62f4973.png
# /kaggle/input/datasets/dasandco/clindataset/test/171388f8091a33de18fa9def04b01042.png
# /kaggle/input/datasets/dasandco/clindataset/test/5a823d8330fbfc71c32173de09b74b01.png
# /kaggle/input/datasets/dasandco/clindataset/test/d0615f853a7deeec90f8b1bf30269fcc.png
# /kaggle/input/datasets/dasandco/clindataset/test/6a31846520f47386beb48675231cde3b.png
# /kaggle/input/datasets/dasandco/clindataset/test/69cdda9dc9e51f15384964918ef50806.png
# /kaggle/input/datasets/dasandco/clindataset/test/fb3feb007c2e3a70ddc7cec5041da44b.png
# /kaggle/input/datasets/dasandco/clindataset/test/c872af6db5f8dc838fcbbed78666bdd7.png
# /kaggle/input/datasets/dasandco/clindataset/test/f62a8210fdd97badd3a850adb5cd2d95.png
# /kaggle/input/datasets/dasandco/clindataset/test/ab5b4a334ecfc9544fb26cc268f85794.png
# /kaggle/input/datasets/dasandco/clindataset/test/5c696936abfc9bbded3d8fd2fa853678.png
# /kaggle/input/datasets/dasandco/clindataset/test/f026b34e04a2bfc6327f2218cf47cd73.png
# /kaggle/input/datasets/dasandco/clindataset/test/e244fb86e085ac10727602e7ab36971b.png
# /kaggle/input/datasets/dasandco/clindataset/test/87d52b0c51edffcdd87793fe348aed71.png
# /kaggle/input/datasets/dasandco/clindataset/test/3b5957a38160102563037a3769a383be.png
# /kaggle/input/datasets/dasandco/clindataset/test/f8959ec07e6b04f0e422f2a8fb18e074.png
# /kaggle/input/datasets/dasandco/clindataset/test/9d19cfe48e499605ca146bd93557d413.png
# /kaggle/input/datasets/dasandco/clindataset/test/512ab0e4091190c453987236dd18c14e.png
# /kaggle/input/datasets/dasandco/clindataset/test/988187e27dd2b73c6d428ff80e47b019.png
# /kaggle/input/datasets/dasandco/clindataset/test/b9d474f14b730f98f89ebacc42de9dcf.png
# /kaggle/input/datasets/dasandco/clindataset/test/3f76b4107e59e33bfded211d2f95d4f4.png
# /kaggle/input/datasets/dasandco/clindataset/test/2634fcd5139b26569a4d3ad23ee1beb9.png
# /kaggle/input/datasets/dasandco/clindataset/test/f5de7e513d2c4085e8b7fd6b5e5db57a.png
# /kaggle/input/datasets/dasandco/clindataset/test/528800fde9832ed21a8c8c6f45cddf14.png
# /kaggle/input/datasets/dasandco/clindataset/test/94991be117227a4da154ae9d49583695.png
# /kaggle/input/datasets/dasandco/clindataset/test/ce0b406c318471eb14c98f9acb081955.png
# /kaggle/input/datasets/dasandco/clindataset/test/fe07298fa1a9109de51c57e56a202df3.png
# /kaggle/input/datasets/dasandco/clindataset/test/27a6da23941b4f586a6812b2d26e61dd.png
# /kaggle/input/datasets/dasandco/clindataset/test/2b004c4cb35e703a7b28d5f3d80ac310.png
# /kaggle/input/datasets/dasandco/clindataset/test/e0dd17b0230ee5b43df7413bc89a70e5.png
# /kaggle/input/datasets/dasandco/clindataset/test/c34ccf37fcb956312549d7a582f19788.png
# /kaggle/input/datasets/dasandco/clindataset/test/3d91a84170a65127a0d998987962dd07.png
# /kaggle/input/datasets/dasandco/clindataset/test/cb8fb8fcb4cc5eaa943063e6e318033a.png
# /kaggle/input/datasets/dasandco/clindataset/test/a36217236c03b1daaa338c22cdbbab87.png
# /kaggle/input/datasets/dasandco/clindataset/test/79b6946338c30268ead5a6253484f852.png
# /kaggle/input/datasets/dasandco/clindataset/test/88555f70eddbd1b7f5153f78c180a3f3.png
# /kaggle/input/datasets/dasandco/clindataset/test/b91c79d745aaf2676d55c05b895171f4.png
# /kaggle/input/datasets/dasandco/clindataset/test/3857dfdfba3a8a401121776389818b72.png
# /kaggle/input/datasets/dasandco/clindataset/test/dd37fc55e9270de5a365efcd06593348.png
# /kaggle/input/datasets/dasandco/clindataset/test/6fdc6a34720c31d685942b7bb44f9612.png
# /kaggle/input/datasets/dasandco/clindataset/test/f951f6a6d4fd2ac09f5e95a33c731a38.png
# /kaggle/input/datasets/dasandco/clindataset/test/9b43a48d28746e26aa54baa1e025e8f4.png
# /kaggle/input/datasets/dasandco/clindataset/test/ca40cec6911dc19ae5a22ef7b474eea9.png
# /kaggle/input/datasets/dasandco/clindataset/test/bf89d440d622cb288d209ac9b7d63a19.png
# /kaggle/input/datasets/dasandco/clindataset/test/76482dd89d7d8ea3650e9a0b8e01aba6.png
# /kaggle/input/datasets/dasandco/clindataset/test/04669ec4821d2dde14eb2f9a3f47eb7e.png
# /kaggle/input/datasets/dasandco/clindataset/test/c327595fc9f648b5deacf0dbf3c4533c.png
# /kaggle/input/datasets/dasandco/clindataset/test/0b7b8344c7c39373cfddf21a7339f206.png
# /kaggle/input/datasets/dasandco/clindataset/test/f3da3f6e8cbc9b17d27754339b0b2311.png
# /kaggle/input/datasets/dasandco/clindataset/test/094d5c1af40f7f565d8d68cf28c06ba5.png
# /kaggle/input/datasets/dasandco/clindataset/test/474007ded9b6b99e3619a705ef34d0dc.png
# /kaggle/input/datasets/dasandco/clindataset/test/2c46afc6145ab7743ca9828389a4d892.png
# /kaggle/input/datasets/dasandco/clindataset/test/acc6f0b29ac46e8211ee8af34623d226.png
# /kaggle/input/datasets/dasandco/clindataset/test/79b547f424c97c52e714d6e808035787.png
# /kaggle/input/datasets/dasandco/clindataset/test/ba069b56d87a5ff7be250ed5abebcc07.png
# /kaggle/input/datasets/dasandco/clindataset/test/5b26309e228cdffb49fee96063e2c880.png
# /kaggle/input/datasets/dasandco/clindataset/test/efa7592fab822d9a1d6dc92d31e41fa1.png
# /kaggle/input/datasets/dasandco/clindataset/test/047815a469503dfe21da4a12e2514a15.png
# /kaggle/input/datasets/dasandco/clindataset/test/8e9dbebe9681191780dd66779a27a663.png
# /kaggle/input/datasets/dasandco/clindataset/test/a384e99cde85590d5d4273d65b921282.png
# /kaggle/input/datasets/dasandco/clindataset/test/de09c63ee469c67331ed80c4ec0d325c.png
# /kaggle/input/datasets/dasandco/clindataset/test/6262074ab507148344a09ead5941c3b8.png
# /kaggle/input/datasets/dasandco/clindataset/test/86f163288f42611c975cbc28990cadd3.png
# /kaggle/input/datasets/dasandco/clindataset/test/dc62f6cad2b946f4ae0b68626b419bf0.png
# /kaggle/input/datasets/dasandco/clindataset/test/84ab46d62cc73aa48c4c219074638067.png
# /kaggle/input/datasets/dasandco/clindataset/test/9060abafbf20514eb23dacaec98e5001.png
# /kaggle/input/datasets/dasandco/clindataset/test/8c7341b62afed8980c0cfa1659909be3.png
# /kaggle/input/datasets/dasandco/clindataset/test/83de33a22bd34496e5a48e703757f955.png
# /kaggle/input/datasets/dasandco/clindataset/test/c4ee0ef309fe9cda88a619df32e7f017.png
# /kaggle/input/datasets/dasandco/clindataset/test/cb8934ba47f04d30c7327ca23efce944.png
# /kaggle/input/datasets/dasandco/clindataset/test/0c26e997c79d2a3149cf1a62c9444554.png
# /kaggle/input/datasets/dasandco/clindataset/test/13db1898f2d711db4aaf0b2a9a4059cd.png
# /kaggle/input/datasets/dasandco/clindataset/test/1deeb557e49b03764d434bad3c7bdd35.png
# /kaggle/input/datasets/dasandco/clindataset/test/49ff79c0235064bd067c31148066acf0.png
# /kaggle/input/datasets/dasandco/clindataset/test/96b106d836d2b4f16362d3a1d1f767a5.png
# /kaggle/input/datasets/dasandco/clindataset/test/d2237da4e95c5f126e951a849e27432e.png
# /kaggle/input/datasets/dasandco/clindataset/test/f5f77203f00504c40b45a65d23cd8948.png
# /kaggle/input/datasets/dasandco/clindataset/test/d70f75311a5e09f9c97c5aedf915f313.png
# /kaggle/input/datasets/dasandco/clindataset/test/fd332164e7924efb4e11f3186bc8fa4d.png
# /kaggle/input/datasets/dasandco/clindataset/test/775aa6a334426b6dc282c61c48478a87.png
# /kaggle/input/datasets/dasandco/clindataset/test/a1e9c815d63650be13b90158b6523c08.png
# /kaggle/input/datasets/dasandco/clindataset/test/cd65d44ae610dd001da9b33c3047b6c1.png
# /kaggle/input/datasets/dasandco/clindataset/test/44a4ac9c03955122caf8db97ae2fcec6.png
# /kaggle/input/datasets/dasandco/clindataset/test/55a3c0036c2d994975cfd350a79cf69e.png
# /kaggle/input/datasets/dasandco/clindataset/test/df5c9296ecae6da1288c490c37c8e3fc.png
# /kaggle/input/datasets/dasandco/clindataset/test/8d612aaeaf1b5a01971cbdba49b37fdb.png
# /kaggle/input/datasets/dasandco/clindataset/test/4a78111ddffd59513a73874c9978b3c2.png
# /kaggle/input/datasets/dasandco/clindataset/test/330c8fe642a041f281f7e7cad8ac2f7c.png
# /kaggle/input/datasets/dasandco/clindataset/test/b56a27064980bc682ef60687a7938dc0.png
# /kaggle/input/datasets/dasandco/clindataset/test/b87fe4c1166680aa2e67644306baa246.png
# /kaggle/input/datasets/dasandco/clindataset/test/0e580dda54b8d1df7e3a888c41e69704.png
# /kaggle/input/datasets/dasandco/clindataset/test/8b783188befa28d99bbf268a7f30bf0c.png
# /kaggle/input/datasets/dasandco/clindataset/test/6039aea81ebf9094b5b3a1be940e09eb.png
# /kaggle/input/datasets/dasandco/clindataset/test/db050c843cfa1c40c2336f5628cebbbf.png
# /kaggle/input/datasets/dasandco/clindataset/test/38d60e4b63eeca0de18a1539dc527c93.png
# /kaggle/input/datasets/dasandco/clindataset/test/1e41c551c741b13ef41f540a6428058b.png
# /kaggle/input/datasets/dasandco/clindataset/test/cdb9c0046cc8f9e32fcafc5517000525.png
# /kaggle/input/datasets/dasandco/clindataset/test/69d19f0d8ac223581188a5adf05cd313.png
# /kaggle/input/datasets/dasandco/clindataset/test/e626e81df9243e43371c8881fbc6d8b7.png
# /kaggle/input/datasets/dasandco/clindataset/test/a34f54c73ecd89db6155fab8cec6b999.png
# /kaggle/input/datasets/dasandco/clindataset/test/ef42c05690b4c16e88cf39481420b779.png
# /kaggle/input/datasets/dasandco/clindataset/test/5d47fc0830ff38a5a584e9fc83928990.png
# /kaggle/input/datasets/dasandco/clindataset/test/32f4fc5f09a10e5dd9bbdf35d7656fb6.png
# /kaggle/input/datasets/dasandco/clindataset/test/90fcb945ce4bd77f9d7eb0cf3b7c0c75.png
# /kaggle/input/datasets/dasandco/clindataset/test/6e7d48015a85db1c2bc29bf3479e598f.png
# /kaggle/input/datasets/dasandco/clindataset/test/926f386ea35e891d7bfbcf9cab111866.png
# /kaggle/input/datasets/dasandco/clindataset/test/e6f7ba58d99ec609df2460c60b8409ab.png
# /kaggle/input/datasets/dasandco/clindataset/test/fd1952a0bbb148711493e3fd73ba1160.png
# /kaggle/input/datasets/dasandco/clindataset/test/ed8eee7061e062987cb2385657477236.png
# /kaggle/input/datasets/dasandco/clindataset/test/38ad783850c6ef47e04130ae94af93df.png
# /kaggle/input/datasets/dasandco/clindataset/test/e1c35c4312a8aa97233d3b88fb07b033.png
# /kaggle/input/datasets/dasandco/clindataset/test/fc4380d16e53e9b9bad5942b31d75f48.png
# /kaggle/input/datasets/dasandco/clindataset/test/154dca2bde84a7434044daf0e61c5b69.png
# /kaggle/input/datasets/dasandco/clindataset/test/af585facfdf8aea6ca8175f5bc2b7c6e.png
# /kaggle/input/datasets/dasandco/clindataset/test/68586360d876ffd615409150466439f2.png
# /kaggle/input/datasets/dasandco/clindataset/test/5bac00dc9f948cebf2b3abe05a1ed729.png
# /kaggle/input/datasets/dasandco/clindataset/test/c359405507bb499761ca794c4951dd57.png
# /kaggle/input/datasets/dasandco/clindataset/test/d44bdbad1399ee98febd7336ef8f1de4.png
# /kaggle/input/datasets/dasandco/clindataset/test/59c201e80a79922c74bf490f5f571369.png
# /kaggle/input/datasets/dasandco/clindataset/test/61073332776c189abf3844bb71f990ab.png
# /kaggle/input/datasets/dasandco/clindataset/test/77b20dccfcee611b676bbfa760f883d3.png
# /kaggle/input/datasets/dasandco/clindataset/test/b310740e310e57b4e817bc1eea810695.png
# /kaggle/input/datasets/dasandco/clindataset/test/786fa2f1244ca842e96cc6afb0f28870.png
# /kaggle/input/datasets/dasandco/clindataset/test/ebedd93f45508cb21815ef2b996e5026.png
# /kaggle/input/datasets/dasandco/clindataset/test/7d9e13dac6ed48dbd0577c3c65b214eb.png
# /kaggle/input/datasets/dasandco/clindataset/test/63d11e1a4e6167f0625d0276fa926a47.png
# /kaggle/input/datasets/dasandco/clindataset/test/a9f5053df6cf18b5e52173b038bddcad.png
# /kaggle/input/datasets/dasandco/clindataset/test/f3426b51acbf433d03c5f84a5d16c0d3.png
# /kaggle/input/datasets/dasandco/clindataset/test/536b5b1ff8d718e73afa20299daa9578.png
# /kaggle/input/datasets/dasandco/clindataset/test/97d10edc0bd4a9bdf9265467678944ae.png
# /kaggle/input/datasets/dasandco/clindataset/test/191b17a545a133660df08ad6b228c7ea.png
# /kaggle/input/datasets/dasandco/clindataset/test/cc52d987264b9fa0ce8a0debcbf435ee.png
# /kaggle/input/datasets/dasandco/clindataset/test/52e9686ffccd0f4d3a6c58de8a12259b.png
# /kaggle/input/datasets/dasandco/clindataset/test/15bb0fd575ecbe78c812dfb4eedd4b77.png
# /kaggle/input/datasets/dasandco/clindataset/test/c2e13e12172f1d2b7e4a8e784b4b16c8.png
# /kaggle/input/datasets/dasandco/clindataset/test/688ecdb1a4e994d42b5a50a8c4a9736f.png
# /kaggle/input/datasets/dasandco/clindataset/test/5f6e71dbd4bfb41dd6ba455f38b55b48.png
# /kaggle/input/datasets/dasandco/clindataset/test/e54b5a593bc03c789ecdc18d8270964e.png
# /kaggle/input/datasets/dasandco/clindataset/test/7d1370ec3e5406ad436adf55a3bcf6f4.png
# /kaggle/input/datasets/dasandco/clindataset/test/690bb572300ef08bbbb7ebf4196099cf.png
# /kaggle/input/datasets/dasandco/clindataset/test/6c0557a8c8475e92ba4118e480157ff5.png
# /kaggle/input/datasets/dasandco/clindataset/test/a501e9ea8988356d9bf03155518dad34.png
# /kaggle/input/datasets/dasandco/clindataset/test/6dd5ddb94bf5028c69056c4d9af92cd9.png
# /kaggle/input/datasets/dasandco/clindataset/test/42d7070a36e7edfa295f9aea2f472e6b.png
# /kaggle/input/datasets/dasandco/clindataset/test/728b3cf755f42fd628ff5fee7bf338d5.png
# /kaggle/input/datasets/dasandco/clindataset/test/c60b8c80551ad7d90c91c3097deb160e.png
# /kaggle/input/datasets/dasandco/clindataset/test/b24786ead7a3022992f42c4bc7802ff1.png
# /kaggle/input/datasets/dasandco/clindataset/test/8e45289dba71354bafe44794b7d60d2c.png
# /kaggle/input/datasets/dasandco/clindataset/test/a226a88f4b8f66c2eba7b974ab8d510d.png
# /kaggle/input/datasets/dasandco/clindataset/test/fe52d8c7ce9e6f9435fcd3438aa19da7.png
# /kaggle/input/datasets/dasandco/clindataset/test/b38be7898a845062393e06bb52cefc2d.png
# /kaggle/input/datasets/dasandco/clindataset/test/3f6b6e7041b06528c5629fb7de92d61e.png
# /kaggle/input/datasets/dasandco/clindataset/test/6b94fef0e417c083388ba961b1d2786a.png
# /kaggle/input/datasets/dasandco/clindataset/test/26b335d3fb7b871bc7714c05421de9a5.png
# /kaggle/input/datasets/dasandco/clindataset/test/a9e40cab375d5e1ce347b4f5587d7579.png
# /kaggle/input/datasets/dasandco/clindataset/test/5f6f2b299b3563b39f0a81dc4045f38a.png
# /kaggle/input/datasets/dasandco/clindataset/test/384ee8c20076c44adbe60bfe7e805869.png
# /kaggle/input/datasets/dasandco/clindataset/test/cae5070a27b63070ecee61beafa2c8c4.png
# /kaggle/input/datasets/dasandco/clindataset/test/3d4c07ae432d5834781d532d833d75ac.png
# /kaggle/input/datasets/dasandco/clindataset/test/6be87996a6f4e9339892c7b8c3af42f3.png
# /kaggle/input/datasets/dasandco/clindataset/test/0ecb6d6e449d5f71b183a6f7fe214c10.png
# /kaggle/input/datasets/dasandco/clindataset/test/4b92edbb7f4cfebd83b4562c578d22c7.png
# /kaggle/input/datasets/dasandco/clindataset/test/97c27cc1254725212a62ca9af162d54d.png
# /kaggle/input/datasets/dasandco/clindataset/test/d6ac4b653b357bcebaff24830d8423cb.png
# /kaggle/input/datasets/dasandco/clindataset/test/d0d647dd59a4b1fb3ceb3aee3a09282a.png
# /kaggle/input/datasets/dasandco/clindataset/test/fb1150a90723df92e2385c956db5aeef.png
# /kaggle/input/datasets/dasandco/clindataset/test/90298b04a0c568ee2144c3431711b30e.png
# /kaggle/input/datasets/dasandco/clindataset/test/884f2b574d9600dd52f4a04c9aa3a230.png
# /kaggle/input/datasets/dasandco/clindataset/test/0a1addecfc432a1b425d61fe57bc29d2.png
# /kaggle/input/datasets/dasandco/clindataset/test/c9ded524aabc60309722651b535ab79a.png
# /kaggle/input/datasets/dasandco/clindataset/test/0713502741102f3e494fb39bbd9f9571.png
# /kaggle/input/datasets/dasandco/clindataset/test/3297d4a571f2259e8699427999a79121.png
# /kaggle/input/datasets/dasandco/clindataset/test/4593b44cd46a5ec9c8f341a16ddcba07.png
# /kaggle/input/datasets/dasandco/clindataset/test/31043d30ee29726c185d655800f025ec.png
# /kaggle/input/datasets/dasandco/clindataset/test/74a3a1f2bbeacbfe81b567713d01cc85.png
# /kaggle/input/datasets/dasandco/clindataset/test/73899609bfb60b2fd74a699b2e5add8c.png
# /kaggle/input/datasets/dasandco/clindataset/test/eb355cf2855e493443600ab7e8a8d98e.png
# /kaggle/input/datasets/dasandco/clindataset/test/72a272f0770ae72999e9afa93a5bf024.png
# /kaggle/input/datasets/dasandco/clindataset/test/5bfab539ea74f0a5051707ca62f562b6.png
# /kaggle/input/datasets/dasandco/clindataset/test/e37e6945fda3fe8118a033cc43b247fb.png
# /kaggle/input/datasets/dasandco/clindataset/test/a6c7487aea4a4e9c3bdf351c1ccaeca3.png
# /kaggle/input/datasets/dasandco/clindataset/test/b5db31329914f79adc2225e63238e057.png
# /kaggle/input/datasets/dasandco/clindataset/test/f97f805bdf52c0809cb1bc43da319f64.png
# /kaggle/input/datasets/dasandco/clindataset/test/b6cd281d9e2086509d4aff85866aa1dc.png
# /kaggle/input/datasets/dasandco/clindataset/test/844c43d38ba987837ba7d59a2b0c2436.png
# /kaggle/input/datasets/dasandco/clindataset/test/47d8960b72621abb40a2544697b6308f.png
# /kaggle/input/datasets/dasandco/clindataset/test/71ae8a44d7e82a2d5672d04d3d7b48f8.png
# /kaggle/input/datasets/dasandco/clindataset/test/271a21b7999e4bf82fb94c8ed51c9e45.png
# /kaggle/input/datasets/dasandco/clindataset/test/12d598be7970fc60aa76bd7c21eef405.png
# /kaggle/input/datasets/dasandco/clindataset/test/997fdbeb9910b1d22539b9311cc565a5.png
# /kaggle/input/datasets/dasandco/clindataset/test/daac34be8b6ca54b0ab1be81733c0d34.png
# /kaggle/input/datasets/dasandco/clindataset/test/dc2cf5d5d0c04cabed09513c44ede6d4.png
# /kaggle/input/datasets/dasandco/clindataset/test/eaa0e16f139fc0f1a3771458025611a1.png
# /kaggle/input/datasets/dasandco/clindataset/test/0a2e45455fe2c76ddbbb5f38ab35f6f2.png
# /kaggle/input/datasets/dasandco/clindataset/test/efafd855e44f0902661c53dc1d5466b4.png
# /kaggle/input/datasets/dasandco/clindataset/test/9fc090c6d79c30b3979bd20b6c05ec83.png
# /kaggle/input/datasets/dasandco/clindataset/test/533bf2420ef58839a93d4fcbec6e27ec.png
# /kaggle/input/datasets/dasandco/clindataset/test/3cb7123b676ed1963d77850bfe185482.png
# /kaggle/input/datasets/dasandco/clindataset/test/74b23792db329cff5843e36efb8aa65a.png
# /kaggle/input/datasets/dasandco/clindataset/test/137ac53870d1ad70a105130b93774949.png
# /kaggle/input/datasets/dasandco/clindataset/test/e796ffb0dc7afc67c75d4896a703ff8e.png
# /kaggle/input/datasets/dasandco/clindataset/test/28d11d6696649471d0af4e67f7126299.png
# /kaggle/input/datasets/dasandco/clindataset/test/331d6f73321a73102327f7cff11ec842.png
# /kaggle/input/datasets/dasandco/clindataset/test/e48737e0cc1a1fe43b0a02484894eaf0.png
# /kaggle/input/datasets/dasandco/clindataset/test/5a2e907a3101a321fb0906de1a110006.png
# /kaggle/input/datasets/dasandco/clindataset/test/fe619a02b19b72ad527dc3e8642f4afd.png
# /kaggle/input/datasets/dasandco/clindataset/test/7e198e152ead58293763b80301b53ea7.png
# /kaggle/input/datasets/dasandco/clindataset/test/e5f707e4fcf1763d282bf7d911c6d345.png
# /kaggle/input/datasets/dasandco/clindataset/test/3c134ccada9f182596bf6107b0dabb8d.png
# /kaggle/input/datasets/dasandco/clindataset/test/5927e15c854e4b6ba3fda0539251b91a.png
# /kaggle/input/datasets/dasandco/clindataset/test/e47174b6f466ff95ff39fe25a8c6638d.png
# /kaggle/input/datasets/dasandco/clindataset/test/225fa92b59afa8d1e96a9b3a5291aaaf.png
# /kaggle/input/datasets/dasandco/clindataset/test/74529936ae10f51ecfb193b3f504fb50.png
# /kaggle/input/datasets/dasandco/clindataset/test/6039745a7cf89b4f65da84eaa8c1a226.png
# /kaggle/input/datasets/dasandco/clindataset/test/8ecee848dad45a30b6a0f80f6524a3cd.png
# /kaggle/input/datasets/dasandco/clindataset/test/4b53f1475d0e4f4b617e7e3cb43bda2c.png
# /kaggle/input/datasets/dasandco/clindataset/test/29fc11e345d3a084f33fda5c43686076.png
# /kaggle/input/datasets/dasandco/clindataset/test/fd0f5d8a369ce5026ea3be06a64980f5.png
# /kaggle/input/datasets/dasandco/clindataset/test/605186158128f2160564d7b3c9898db3.png
# /kaggle/input/datasets/dasandco/clindataset/test/5157d5c9b1f0004b29310652ea54e825.png
# /kaggle/input/datasets/dasandco/clindataset/test/419aa74d3b1447debce1775ba7084c29.png
# /kaggle/input/datasets/dasandco/clindataset/test/74e44965f52b614f4f200468b9594382.png
# /kaggle/input/datasets/dasandco/clindataset/test/ace60710b86a4f9e247f6a04c0b64418.png
# /kaggle/input/datasets/dasandco/clindataset/test/127e2784b91becce4ac297255904033e.png
# /kaggle/input/datasets/dasandco/clindataset/test/eee52f4fd64d6f8a197abdf7ac27fd1f.png
# /kaggle/input/datasets/dasandco/clindataset/test/521737fe7ce420e5fe1864c36f1f1865.png
# /kaggle/input/datasets/dasandco/clindataset/test/ec91e38bb8201229cc989e5cc7f4aa6b.png
# /kaggle/input/datasets/dasandco/clindataset/test/0c6036df3708fe77c1c76498240d6774.png
# /kaggle/input/datasets/dasandco/clindataset/test/d65bd4d5a6fae0e0f6833e1a7dd48399.png
# /kaggle/input/datasets/dasandco/clindataset/test/5085aa895168d112f671ae18b22dc0df.png
# /kaggle/input/datasets/dasandco/clindataset/test/5817c3257a58b34a43122134fc3115f9.png
# /kaggle/input/datasets/dasandco/clindataset/test/f4e77a5ddc822faaf55570590689466b.png
# /kaggle/input/datasets/dasandco/clindataset/test/6e930ab867c57f51c91565b9d251ecc0.png
# /kaggle/input/datasets/dasandco/clindataset/test/4cc22fdb9c33ee883ca3f033c62928c4.png
# /kaggle/input/datasets/dasandco/clindataset/test/afea5cd9971b43df0e0e56faa5ec9e0a.png
# /kaggle/input/datasets/dasandco/clindataset/test/b12232ebf575db0226671621146f76e1.png
# /kaggle/input/datasets/dasandco/clindataset/test/c58fac126b9ea21f2188b3c57dd3beed.png
# /kaggle/input/datasets/dasandco/clindataset/test/b1876d26a3f3cc44a8c667aa2a8a972c.png
# /kaggle/input/datasets/dasandco/clindataset/test/730f25f4ac6b4fd10d9cf582494c911e.png
# /kaggle/input/datasets/dasandco/clindataset/test/e911e444e80e7a7a0a44b666513e282e.png
# /kaggle/input/datasets/dasandco/clindataset/test/4e60eda03b7df9196e6309009114f54b.png
# /kaggle/input/datasets/dasandco/clindataset/test/af2c39b21636af413907f7f1cf658446.png
# /kaggle/input/datasets/dasandco/clindataset/test/88026d37fe4202ab073fa838da4fa438.png
# /kaggle/input/datasets/dasandco/clindataset/test/311301e3ac19b4b8eda85672e625b2e8.png
# /kaggle/input/datasets/dasandco/clindataset/test/7b9e39af7921e086e5904755d5535b31.png
# /kaggle/input/datasets/dasandco/clindataset/test/f6c2af19972fcdff152db631020f4784.png
# /kaggle/input/datasets/dasandco/clindataset/test/c4c6b6599a13c1c914b839f7a9f79540.png
# /kaggle/input/datasets/dasandco/clindataset/test/ded48559b86e307d86f522abb9bab7d1.png
# /kaggle/input/datasets/dasandco/clindataset/test/7f6b660751fb873941366907f14d16d3.png
# /kaggle/input/datasets/dasandco/clindataset/test/3b55e52750fa2737857d05526f196b18.png
# /kaggle/input/datasets/dasandco/clindataset/test/53675dd5b4676fb96d77abf225209f41.png
# /kaggle/input/datasets/dasandco/clindataset/test/17ead023e20603e9df9f2a3f326b2344.png
# /kaggle/input/datasets/dasandco/clindataset/test/26fa2f95e008965bec79eddf40220618.png
# /kaggle/input/datasets/dasandco/clindataset/test/874ac8cb7b030ee4356d0b1bf54f3bd6.png
# /kaggle/input/datasets/dasandco/clindataset/test/4910dbe4c6e17a35ed2ba6e7f3d04ef8.png
# /kaggle/input/datasets/dasandco/clindataset/test/54fb9abeb8e92ec3f690a7455d892c3a.png
# /kaggle/input/datasets/dasandco/clindataset/test/03f9ce3f34a38cf5c6411acd8fd4c5ff.png
# /kaggle/input/datasets/dasandco/clindataset/test/36b6d5f8f49d605ee5f27fbd80b96d5a.png
# /kaggle/input/datasets/dasandco/clindataset/test/dddab655208efc25d98e16790db35f25.png
# /kaggle/input/datasets/dasandco/clindataset/test/acb798cac2ce66c6c9b1570fab4e4adc.png
# /kaggle/input/datasets/dasandco/clindataset/test/d668f847d1fbfef0784961b91ad913bd.png
# /kaggle/input/datasets/dasandco/clindataset/test/6ae66f1bc9c08766adb65d366a60e2b0.png
# /kaggle/input/datasets/dasandco/clindataset/test/4fef5faf22105d6c29f218236dd44d66.png
# /kaggle/input/datasets/dasandco/clindataset/test/c85bd341e70f12a1653e6d3a48225e55.png
# /kaggle/input/datasets/dasandco/clindataset/test/97e10e9ae645d625489ae5df9548c589.png
# /kaggle/input/datasets/dasandco/clindataset/test/61c0f32c4fad9cadae858544705625dd.png
# /kaggle/input/datasets/dasandco/clindataset/test/40497da14aafc428210b623fc8445288.png
# /kaggle/input/datasets/dasandco/clindataset/test/12ed43ece0b7bff835c1461a7f501cdb.png
# /kaggle/input/datasets/dasandco/clindataset/test/074e3cceb0c1677a1ad0dbff31167d7d.png
# /kaggle/input/datasets/dasandco/clindataset/test/cdd5481fd9376b5e7828aec48799255a.png
# /kaggle/input/datasets/dasandco/clindataset/test/7158cb1a21c2af6490567b0fe1dfaae0.png
# /kaggle/input/datasets/dasandco/clindataset/test/71e9666b94e09e7485ab6350036faea6.png
# /kaggle/input/datasets/dasandco/clindataset/test/a8eea443a1b6ff5a66a5b3d9ca3b43ec.png
# /kaggle/input/datasets/dasandco/clindataset/test/f631a7b16aa5a67caf2cbe807c068191.png
# /kaggle/input/datasets/dasandco/clindataset/test/8622b8fb70af2568eb36fe1e9bf944df.png
# /kaggle/input/datasets/dasandco/clindataset/test/ef80aa87c223632f7522be728bd62e2e.png
# /kaggle/input/datasets/dasandco/clindataset/test/82913cf4e449decbc5195cffc2422b4d.png
# /kaggle/input/datasets/dasandco/clindataset/test/e27172128ec1e2610400fd1312f53896.png
# /kaggle/input/datasets/dasandco/clindataset/test/ecbd6ed341b1c3867c5f29be7ab776b1.png
# /kaggle/input/datasets/dasandco/clindataset/test/7b60d69158c11381cad26574b327c723.png
# /kaggle/input/datasets/dasandco/clindataset/test/3ef5a2d445ede454793f144d462faaab.png
# /kaggle/input/datasets/dasandco/clindataset/test/86f879c042c8a2860eb6f3177d374998.png
# /kaggle/input/datasets/dasandco/clindataset/test/e1d40460f86f7b92f033b08d04b4ea6a.png
# /kaggle/input/datasets/dasandco/clindataset/test/bef145a9dd524d1afdb2394c953bb978.png
# /kaggle/input/datasets/dasandco/clindataset/test/e82e5f7cf9eaffcf52a36ee49e4b576a.png
# /kaggle/input/datasets/dasandco/clindataset/test/3215a7d4dc49d93b54635b85df536b8f.png
# /kaggle/input/datasets/dasandco/clindataset/test/5254623fe2189d170d018917e5833c79.png
# /kaggle/input/datasets/dasandco/clindataset/test/6cf8916303a07f3909297be170f21f7a.png
# /kaggle/input/datasets/dasandco/clindataset/test/173f8f59c15a521dc3ea16ee8783159c.png
# /kaggle/input/datasets/dasandco/clindataset/test/6100bc75e0a668c382d92d5eb9038076.png
# /kaggle/input/datasets/dasandco/clindataset/test/85cfce301b95db7beeaeeee8d9b44b31.png
# /kaggle/input/datasets/dasandco/clindataset/test/342f1081f906354b4cca70450b27d32a.png
# /kaggle/input/datasets/dasandco/clindataset/test/3f51f6bbad915b2d088bdceea490f3ff.png
# /kaggle/input/datasets/dasandco/clindataset/test/a87c6ab4132c0ef29ebf51bc418ce921.png
# /kaggle/input/datasets/dasandco/clindataset/test/89f9bf838081221588361f1da1e9a81a.png
# /kaggle/input/datasets/dasandco/clindataset/test/98ed8a6f5992837800be0732813b9c57.png
# /kaggle/input/datasets/dasandco/clindataset/test/9b64cc50d04171fc9dc5bb5880bff3d4.png
# /kaggle/input/datasets/dasandco/clindataset/test/f6fa36dcae4cfd831f6d5a6bd4520a59.png
# /kaggle/input/datasets/dasandco/clindataset/test/58baa9b0269a2987f5475a554033c4b1.png
# /kaggle/input/datasets/dasandco/clindataset/test/ca5305844c45ccfa56bf83c4bcf8fa5a.png
# /kaggle/input/datasets/dasandco/clindataset/test/818a1e7fcce109b3640d73dcf9ae74da.png
# /kaggle/input/datasets/dasandco/clindataset/test/25d536e3c96e22c7c258d2ed859c304a.png
# /kaggle/input/datasets/dasandco/clindataset/test/0b8ec8f17db23936e86de9ca3f36d206.png
# /kaggle/input/datasets/dasandco/clindataset/test/9a581d10b649544c3bf01227bb2d728f.png
# /kaggle/input/datasets/dasandco/clindataset/test/c113a6afc94fc8b97464b31c9de085ab.png
# /kaggle/input/datasets/dasandco/clindataset/test/65e600f7fd5b8cf1c3027e2165585ed8.png
# /kaggle/input/datasets/dasandco/clindataset/test/3185bd3972ec4bc6029fbfe00af919f0.png
# /kaggle/input/datasets/dasandco/clindataset/test/2562f346ed3db617c6cf209d6fbfd384.png
# /kaggle/input/datasets/dasandco/clindataset/test/871e8ae9dc52f1fd45a7cd3068c71d2e.png
# /kaggle/input/datasets/dasandco/clindataset/test/9b7b30c14e12598ee4bd19777ef0557e.png
# /kaggle/input/datasets/dasandco/clindataset/test/69454c090ae1d9ff81da56af7c2d27b8.png
# /kaggle/input/datasets/dasandco/clindataset/test/242e05a5782d6682a43999a2e21096e6.png
# /kaggle/input/datasets/dasandco/clindataset/test/bbded36443480f20efc2a93c6c353369.png
# /kaggle/input/datasets/dasandco/clindataset/test/0f8e45ea561be377320632bcb7348f72.png
# /kaggle/input/datasets/dasandco/clindataset/test/f0310a7e6a81b1a7efc5ef323727e974.png
# /kaggle/input/datasets/dasandco/clindataset/test/548cf3241eba5f1482caac5fbc0b9fee.png
# /kaggle/input/datasets/dasandco/clindataset/test/33a621bb6474d8000c932ce489c4f734.png
# /kaggle/input/datasets/dasandco/clindataset/test/921d2a094965fd081bc7d0d9ac6354b2.png
# /kaggle/input/datasets/dasandco/clindataset/test/5f258fac6e0345f01b8253712e83e454.png
# /kaggle/input/datasets/dasandco/clindataset/test/af2a0be2fe0eed4b198487a185e78e14.png
# /kaggle/input/datasets/dasandco/clindataset/test/d0d2addff91ad7beb1d92126ff74d621.png
# /kaggle/input/datasets/dasandco/clindataset/test/adca1d936c8d6b0cd25c0011894f20dd.png
# /kaggle/input/datasets/dasandco/clindataset/test/bc288b3d6a7c674d372b85133272b09a.png
# /kaggle/input/datasets/dasandco/clindataset/test/25f51d768c59ed4ac52079177d45479f.png
# /kaggle/input/datasets/dasandco/clindataset/test/800ba8f1fac83f75a00762f415780e9f.png
# /kaggle/input/datasets/dasandco/clindataset/test/a98c821850d44edfeb4c87e5b247f384.png
# /kaggle/input/datasets/dasandco/clindataset/test/45a67b52deef6d917675de9efcace27d.png
# /kaggle/input/datasets/dasandco/clindataset/test/e06a136bef44d96402a353c3073f65e5.png
# /kaggle/input/datasets/dasandco/clindataset/test/3d281a2a2c78f8e0713166ed125a183a.png
# /kaggle/input/datasets/dasandco/clindataset/test/8dec5497ecc246766acfba5a4be4e619.png
# /kaggle/input/datasets/dasandco/clindataset/test/d5d43ffa4e64e63ccd92c40397d6b48b.png
# /kaggle/input/datasets/dasandco/clindataset/test/fd2e07088ff35c77448f636ad1816039.png
# /kaggle/input/datasets/dasandco/clindataset/test/27660605ca5cdffc3a99e9f2f167b1ff.png
# /kaggle/input/datasets/dasandco/clindataset/test/325fa15bdeaf8dfe6cf63a82fad30228.png
# /kaggle/input/datasets/dasandco/clindataset/test/bc174956c6e2b4ba65b4839da84f8aee.png
# /kaggle/input/datasets/dasandco/clindataset/test/3dcc30d354b4502eb28e3dfbc697756b.png
# /kaggle/input/datasets/dasandco/clindataset/test/33fb234fc2ad20c92d1a556d7c3eb916.png
# /kaggle/input/datasets/dasandco/clindataset/test/a3b5403784ffb7faa00003009aaa1d45.png
# /kaggle/input/datasets/dasandco/clindataset/test/6ce0806845f2f73ef1665353979d581f.png
# /kaggle/input/datasets/dasandco/clindataset/test/7087e60b5382e43856c13a72ca679c6e.png
# /kaggle/input/datasets/dasandco/clindataset/test/d49baee1abbde153ef985a0091d603f8.png
# /kaggle/input/datasets/dasandco/clindataset/test/e27295afee6a7fda9e520f2e3f4ed2ef.png
# /kaggle/input/datasets/dasandco/clindataset/test/4e6377304c6519ef809c744ef376c319.png
# /kaggle/input/datasets/dasandco/clindataset/test/bcb4b44fea2b97470a3cb8534a082421.png
# /kaggle/input/datasets/dasandco/clindataset/test/509b0a6e32afb4094897a916b3c72486.png
# /kaggle/input/datasets/dasandco/clindataset/test/8d598771f57b55e64a2ecd048ac42194.png
# /kaggle/input/datasets/dasandco/clindataset/test/dbd9e1d7586876d95f1f1923db1c830f.png
# /kaggle/input/datasets/dasandco/clindataset/test/5dcc32890d8892aa5583f07b8308f6d9.png
# /kaggle/input/datasets/dasandco/clindataset/test/4fef4a4c55426766f8eaff240f1050dd.png
# /kaggle/input/datasets/dasandco/clindataset/test/a113218469475fef9827360a2f850b3f.png
# /kaggle/input/datasets/dasandco/clindataset/test/f6badb69877d94bde2043ca0ccc971fb.png
# /kaggle/input/datasets/dasandco/clindataset/test/6f8b23eee8e3c3e4e47173d141f9b791.png
# /kaggle/input/datasets/dasandco/clindataset/test/1b78d27f9d6dbeb9296c6b610262c95e.png
# /kaggle/input/datasets/dasandco/clindataset/test/84564d34f32254f20e49bcb6ab603421.png
# /kaggle/input/datasets/dasandco/clindataset/test/6ae67e95de277c280873ec6a0dd3dc01.png
# /kaggle/input/datasets/dasandco/clindataset/test/3533a82817c5bba65a24f2799679fb50.png
# /kaggle/input/datasets/dasandco/clindataset/test/2979cd224774fef9c95a43c4f1e8e721.png
# /kaggle/input/datasets/dasandco/clindataset/test/d43df1abdb9859d5ba04dee128f1c803.png
# /kaggle/input/datasets/dasandco/clindataset/test/6ddfbc87602afc5ef112b401637ef3ae.png
# /kaggle/input/datasets/dasandco/clindataset/test/6f69a6354bed9fabd85e9d5766075075.png
# /kaggle/input/datasets/dasandco/clindataset/test/9cb8ad93052c913e3cce32c0d5ca8e62.png
# /kaggle/input/datasets/dasandco/clindataset/test/439dc69a4c208bef639794335fc7e8aa.png
# /kaggle/input/datasets/dasandco/clindataset/test/b112545c70dffa1f3070ca17ae314782.png
# /kaggle/input/datasets/dasandco/clindataset/test/e4e376d9aae02fa803ea2d9128aa3131.png
# /kaggle/input/datasets/dasandco/clindataset/test/b2026d7a8878474b33490ccc9ac1d0b8.png
# /kaggle/input/datasets/dasandco/clindataset/test/8718fb6c453339e5db252d14328d8ae9.png
# /kaggle/input/datasets/dasandco/clindataset/test/5a719936747485b2902623a89643a508.png
# /kaggle/input/datasets/dasandco/clindataset/test/3097b40e5fe9ed1c66ef81dd98ecefec.png
# /kaggle/input/datasets/dasandco/clindataset/test/db7d9dd61d0814dce97bd87abc05bba1.png
# /kaggle/input/datasets/dasandco/clindataset/test/253feb1e5d47eb3543d0cd0b072df5e5.png
# /kaggle/input/datasets/dasandco/clindataset/test/84d97a74cb6d007c8b4370c07920137c.png
# /kaggle/input/datasets/dasandco/clindataset/test/e6c0951354a0be53f6071e4a85ae5b06.png
# /kaggle/input/datasets/dasandco/clindataset/test/7b29ce6b9a2822aadc7ef891bd2ee88b.png
# /kaggle/input/datasets/dasandco/clindataset/test/e0287e0fab8e6a90dc15dd8eb964931c.png
# /kaggle/input/datasets/dasandco/clindataset/test/6e7d4b9cf93fee47afe3c299da9cd589.png
# /kaggle/input/datasets/dasandco/clindataset/test/aaef5c76717e048a21ca0bbe328e3552.png
# /kaggle/input/datasets/dasandco/clindataset/test/5f7ff740eb512cd79270692b145d9f43.png
# /kaggle/input/datasets/dasandco/clindataset/test/68de8599cb0dad09fd695e507f3ddfd0.png
# /kaggle/input/datasets/dasandco/clindataset/test/cb3b210015a31adab114493e1150eaf8.png
# /kaggle/input/datasets/dasandco/clindataset/test/802ee38a7da17f26985c121f68bb9d26.png
# /kaggle/input/datasets/dasandco/clindataset/test/1663ffcf2520d42473b572deb56b2497.png
# /kaggle/input/datasets/dasandco/clindataset/test/6af0347de5ced3d7daa3c5db56c4ebf4.png
# /kaggle/input/datasets/dasandco/clindataset/test/cb5a71f2ba8bcfe8d6f946fa49245c4b.png
# /kaggle/input/datasets/dasandco/clindataset/test/08d6125cda5ffceb8f235c96179a7061.png
# /kaggle/input/datasets/dasandco/clindataset/test/460283ce802309a67fab5f8d098cc7f1.png
# /kaggle/input/datasets/dasandco/clindataset/test/16f1811f5ce5fef3f8ef60b2fc675af5.png
# /kaggle/input/datasets/dasandco/clindataset/test/f1ae5125f7a72feed87fc0afa919b261.png
# /kaggle/input/datasets/dasandco/clindataset/test/4fcf87976ca07858d6ee9af47b2a719c.png
# /kaggle/input/datasets/dasandco/clindataset/test/19956c66c5528604e1043c766eeba90f.png
# /kaggle/input/datasets/dasandco/clindataset/test/1e87b2befde0db02bf14e75e798e4269.png
# /kaggle/input/datasets/dasandco/clindataset/test/89f04f147e058dd9899c3868fc135e4f.png
# /kaggle/input/datasets/dasandco/clindataset/test/8b44752d98acbc233b093260c0f2061d.png
# /kaggle/input/datasets/dasandco/clindataset/test/187b41878d6dfc41488d4f1f379bbdc1.png
# /kaggle/input/datasets/dasandco/clindataset/test/e59e78c6c661eb4c3daab5df0075e6c6.png
# /kaggle/input/datasets/dasandco/clindataset/test/9a8b1df88ad29e363d897f4806bfe15c.png
# /kaggle/input/datasets/dasandco/clindataset/test/968735441bd2c77d7cfcf4d504b1fd5b.png
# /kaggle/input/datasets/dasandco/clindataset/test/38ca9de33c512c71aa3094a151dd5368.png
# /kaggle/input/datasets/dasandco/clindataset/test/299a26bc4cc1680b6d22047a5a7aca2a.png
# /kaggle/input/datasets/dasandco/clindataset/test/eb70242f7644caa93343aebf7eef793a.png
# /kaggle/input/datasets/dasandco/clindataset/test/cc657609a4dcf498ea39a9586d7ae9b3.png
# /kaggle/input/datasets/dasandco/clindataset/test/2ce9d73f2f2b9809f54f5ced22abb25e.png
# /kaggle/input/datasets/dasandco/clindataset/test/789cba61f30c4c087a6cd97def275aca.png
# /kaggle/input/datasets/dasandco/clindataset/test/fc49e387cd9955fc80d0124967ef303b.png
# /kaggle/input/datasets/dasandco/clindataset/test/25e8a01e7de94f8874d34b9afdd593c5.png
# /kaggle/input/datasets/dasandco/clindataset/test/99f7683a4b94a0cdb5f3b98953647a47.png
# /kaggle/input/datasets/dasandco/clindataset/test/134214ffc7f507842719617ecd5bfc52.png
# /kaggle/input/datasets/dasandco/clindataset/test/6ca2a9acd3421424f26805ef49e9bdff.png
# /kaggle/input/datasets/dasandco/clindataset/test/22e777d8cb8506360407e800070e6ed4.png
# /kaggle/input/datasets/dasandco/clindataset/test/11c92d8711765e3f16b0be225d7d5c03.png
# ...
# /kaggle/input/datasets/dasandco/clindataset/train/fd03dd80e6e2940d7527e52670f3c21a.png
# /kaggle/input/datasets/dasandco/clindataset/train/f2c24b0ee5fc1d417923650b5a7c5532.png
# /kaggle/input/datasets/dasandco/clindataset/train/edd5c7d4d08bce0f94b0eb8b76bc450a.png
# /kaggle/input/datasets/dasandco/clindataset/train/fd3bc4451de23d488123a67048dd6ef4.png
# /kaggle/input/datasets/dasandco/clindataset/train/8c83bbb64a1211b854a10cd1cdde912e.png
# /kaggle/input/datasets/dasandco/clindataset/train/687ca0b62889d06335ba7a3d147baf76.png
# /kaggle/input/datasets/dasandco/clindataset/train/6e48149a34ba1700f265b5e7d9fe0cd1.png
# /kaggle/input/datasets/dasandco/clindataset/train/b76cca59757045fa3cedad238c878354.png
# /kaggle/input/datasets/dasandco/clindataset/train/717b848dae42dc6c33d6d3a5754e690b.png
# /kaggle/input/datasets/dasandco/clindataset/train/89d2c2a6c42bb2bc268b8d535c4f31fa.png
# /kaggle/input/datasets/dasandco/clindataset/train/e926caa8ac837b65b8efcf693a581dfd.png
# /kaggle/input/datasets/dasandco/clindataset/train/7e2c00df012b5314d02508317514e531.png
# /kaggle/input/datasets/dasandco/clindataset/train/1246d654bb8a0b1e713e6d48a485456a.png
# /kaggle/input/datasets/dasandco/clindataset/train/22141f53eba2088f460be5d3f323121b.png
# /kaggle/input/datasets/dasandco/clindataset/train/a9ab4843564feecfc052a300af02cf71.png
# /kaggle/input/datasets/dasandco/clindataset/train/bbddec90a8d4ed86861978fb09267338.png
# /kaggle/input/datasets/dasandco/clindataset/train/5dd28adf45035593337e0af14785f7ae.png
# /kaggle/input/datasets/dasandco/clindataset/train/f0d22c16053fc6b19bbf579a5071287b.png
# /kaggle/input/datasets/dasandco/clindataset/train/72c151dc4106f5cdb97ea9c55e2c2703.png
# /kaggle/input/datasets/dasandco/clindataset/train/e3ceb9b83afd35a505e319807e42338d.png
# /kaggle/input/datasets/dasandco/clindataset/train/d80aefc39fadd237184f3500bbbd84d3.png
# /kaggle/input/datasets/dasandco/clindataset/train/b5cf329f8554a054dda2c6dac556c5dc.png
# /kaggle/input/datasets/dasandco/clindataset/train/23d1c67775a1f20404642b6086b74cc8.png
# /kaggle/input/datasets/dasandco/clindataset/train/deca3ba844d501eb3ea145dc15c2cfb0.png
# /kaggle/input/datasets/dasandco/clindataset/train/d28436f3bcb1f8a129b35a812d5c8cfb.png
# /kaggle/input/datasets/dasandco/clindataset/train/75ecc008a5e1a7f034c309b4f3f1e64e.png
# /kaggle/input/datasets/dasandco/clindataset/train/17f6dee4cb5a49d4831d3be2f3d276d4.png
# /kaggle/input/datasets/dasandco/clindataset/train/71ddd7f7b44aa49dafb8410e8d542ffb.png
# /kaggle/input/datasets/dasandco/clindataset/train/3a7a9cd8aaaa550f5f72ae9fe1707ab9.png
# /kaggle/input/datasets/dasandco/clindataset/train/8333298ed00e375cd2ab46d1a57641bc.png
# /kaggle/input/datasets/dasandco/clindataset/train/530ec5b21e038ebc9c5664a2551198d0.png
# /kaggle/input/datasets/dasandco/clindataset/train/9bec6028a3cc222ea65a170776a82546.png
# /kaggle/input/datasets/dasandco/clindataset/train/ddd286ecdcfdf72a50ce99aa01ba74ca.png
# /kaggle/input/datasets/dasandco/clindataset/train/8072c8f70ffb83e6a82b01aafb25263d.png
# /kaggle/input/datasets/dasandco/clindataset/train/23f1167e98727ee4b2f098240209b7d6.png
# /kaggle/input/datasets/dasandco/clindataset/train/3ea334ae927f1feeaf80e59b5d937c31.png
# /kaggle/input/datasets/dasandco/clindataset/train/2c42c054b21c3a7ff91f13e3b43e5418.png
# /kaggle/input/datasets/dasandco/clindataset/train/47c99f1ff7abe52d6dcdf4414db20e2c.png
# /kaggle/input/datasets/dasandco/clindataset/train/a3cdec3bcaee8dcd461e83d2ecbc95b1.png
# /kaggle/input/datasets/dasandco/clindataset/train/56dac092c516acffda2ffac85f90e9cc.png
# /kaggle/input/datasets/dasandco/clindataset/train/27c69745b5ba6930e94b9b29bd1965ad.png
# /kaggle/input/datasets/dasandco/clindataset/train/24bfefea72970330a9a8013298cf5f51.png
# /kaggle/input/datasets/dasandco/clindataset/train/49bab152b559fd56abb440523f80d368.png
# /kaggle/input/datasets/dasandco/clindataset/train/5e272e3adbdaafb07a7e84a9e62b1a4c.png
# /kaggle/input/datasets/dasandco/clindataset/train/62ff447df5664ab62f41a4ec7011a62d.png
# /kaggle/input/datasets/dasandco/clindataset/train/3da89bf577082524327d6cb2b6c75d0d.png
# /kaggle/input/datasets/dasandco/clindataset/train/014b381459563f39d15b37e327f2766e.png
# /kaggle/input/datasets/dasandco/clindataset/train/cf4491820a0f9dcc902699670620b550.png
# /kaggle/input/datasets/dasandco/clindataset/train/bee427b74f77002c1a4faa71e65d5744.png
# /kaggle/input/datasets/dasandco/clindataset/train/7a012e9ca947bbe8b46b47cd3257fc62.png
# /kaggle/input/datasets/dasandco/clindataset/train/289bc9e9d49d8cb9157e741a3a171004.png
# /kaggle/input/datasets/dasandco/clindataset/train/4ad46eb0e6e47dd1b4ca3c493d755341.png
# /kaggle/input/datasets/dasandco/clindataset/train/335c54cca869510a063780bc0fba7ede.png
# /kaggle/input/datasets/dasandco/clindataset/train/765e35b5a14e3cfbeda2908641004d5a.png
# /kaggle/input/datasets/dasandco/clindataset/train/abc391a77ac9c66e2c6272331c329764.png
# /kaggle/input/datasets/dasandco/clindataset/train/ea00fab3726550241cd51c2750892d36.png
# /kaggle/input/datasets/dasandco/clindataset/train/f0d9c07ca00922f0eaeff329c80c562f.png
# /kaggle/input/datasets/dasandco/clindataset/train/f8c58f156f9bcdba6f1d0d454560c8d4.png
# /kaggle/input/datasets/dasandco/clindataset/train/02d78076ba349f56b20f3467af61ef58.png
# /kaggle/input/datasets/dasandco/clindataset/train/117c218c2534e3d40a6ca0b3d724eb24.png
# /kaggle/input/datasets/dasandco/clindataset/train/ddf1ec27c68bb40da0bebdff2dd95175.png
# /kaggle/input/datasets/dasandco/clindataset/train/bebeb21c6c546a652346ef00d9b3978f.png
# /kaggle/input/datasets/dasandco/clindataset/train/1cebab049689f364d2ba4206bbaf9cd6.png
# /kaggle/input/datasets/dasandco/clindataset/train/2925f7ce2925a44c3ccee312861b0dc1.png
# /kaggle/input/datasets/dasandco/clindataset/train/cfbf4cf50bfdc65b49aa60353700a130.png
# /kaggle/input/datasets/dasandco/clindataset/train/528dd19aa87822d4d1fbc1bca60b1415.png
# /kaggle/input/datasets/dasandco/clindataset/train/07db76e6cc063ce8bb90de18216e8ccf.png
# /kaggle/input/datasets/dasandco/clindataset/train/204b14c0d284a2aa0c75e2e6adf616c3.png
# /kaggle/input/datasets/dasandco/clindataset/train/18a61a07e6f5f13ebfee57fa36cd8b6f.png
# /kaggle/input/datasets/dasandco/clindataset/train/f0105dcab1f42815442e5a2b0247eb21.png
# /kaggle/input/datasets/dasandco/clindataset/train/964cafc7a5ad06e8af2f1ff34ac9f463.png
# /kaggle/input/datasets/dasandco/clindataset/train/cad8e7e5f5034a50d4b1ebb30db533c5.png
# /kaggle/input/datasets/dasandco/clindataset/train/6535a046e90cc4e42bd3ac9598a07e06.png
# /kaggle/input/datasets/dasandco/clindataset/train/502a3c9ce20947359a226af872d52f09.png
# /kaggle/input/datasets/dasandco/clindataset/train/9c9d6d92f17ef2b3145ad8743e11b194.png
# /kaggle/input/datasets/dasandco/clindataset/train/01ce66ee84ef4045a06269aa0f5c2756.png
# /kaggle/input/datasets/dasandco/clindataset/train/82036dda6c748f81f73d4b597ed7f355.png
# /kaggle/input/datasets/dasandco/clindataset/train/e55c49c7b7f2805c5f811c1e356f193a.png
# /kaggle/input/datasets/dasandco/clindataset/train/4d86666aef656a96dbc6cca83eafb36e.png
# /kaggle/input/datasets/dasandco/clindataset/train/43168eb06024ac4634c14f1d386f4136.png
# /kaggle/input/datasets/dasandco/clindataset/train/168cc30b1b173119d9bac94648e55e84.png
# /kaggle/input/datasets/dasandco/clindataset/train/0dda67e8e02513695e2bfdd5a846f03e.png
# /kaggle/input/datasets/dasandco/clindataset/train/2ea80a706ffc413d3c8d8c666e869c43.png
# /kaggle/input/datasets/dasandco/clindataset/train/9607e2f142ad3dbaa2ba8db48dc81daf.png
# /kaggle/input/datasets/dasandco/clindataset/train/1de1fb0878055fe44cd99abcbde7bfc4.png
# /kaggle/input/datasets/dasandco/clindataset/train/23131626dc183b20262da386d09fb1c1.png
# /kaggle/input/datasets/dasandco/clindataset/train/6889e2bb71d3d5625baaf6914785cd2e.png
# /kaggle/input/datasets/dasandco/clindataset/train/f1dfc3bfb919da31d848eda5a20a8258.png
# /kaggle/input/datasets/dasandco/clindataset/train/a9f17d3eb4a8221c3ef0dd12bfec0ba0.png
# /kaggle/input/datasets/dasandco/clindataset/train/c01011537715b0857c86240cb7fa9521.png
# /kaggle/input/datasets/dasandco/clindataset/train/61306376f68f499c2d6e52b56225012b.png
# /kaggle/input/datasets/dasandco/clindataset/train/139282fc433f147aba91c6a99b8376c3.png
# /kaggle/input/datasets/dasandco/clindataset/train/0453de2faeb8d349af739a68d9dee1cb.png
# /kaggle/input/datasets/dasandco/clindataset/train/46e487b18e0988c53bf9056bd3689a6d.png
# /kaggle/input/datasets/dasandco/clindataset/train/e07b82a283ebdbe612c8260a552fa606.png
# /kaggle/input/datasets/dasandco/clindataset/train/5fbefa3cc10484d412c640c489a3efd3.png
# /kaggle/input/datasets/dasandco/clindataset/train/76c39b1acee002408cc8956065ea105e.png
# /kaggle/input/datasets/dasandco/clindataset/train/b810e4520338c941ea9cbb24e5f68dfc.png
# /kaggle/input/datasets/dasandco/clindataset/train/38ccfc0fd67dcb818d05fc640e968a92.png
# /kaggle/input/datasets/dasandco/clindataset/train/d1dfd6ac02ac34ebaf9788ec9b2de1f3.png
# /kaggle/input/datasets/dasandco/clindataset/train/1d63eea24a9f69bc17f1da7af4ffa19a.png
# /kaggle/input/datasets/dasandco/clindataset/train/fca6ec628aaba74b867c27fec104fd3a.png
# /kaggle/input/datasets/dasandco/clindataset/train/7b25f0d67b941270bce319df67d850b2.png
# /kaggle/input/datasets/dasandco/clindataset/train/7686dfb913f7e7bfdcd9cf85e7946d28.png
# /kaggle/input/datasets/dasandco/clindataset/train/12d87958ea1b07f2d31b128f8cd18939.png
# /kaggle/input/datasets/dasandco/clindataset/train/577807f1ee94692b516b0b184b89ab35.png
# /kaggle/input/datasets/dasandco/clindataset/train/f4ff44be77afb9c83670196d67e6417c.png
# /kaggle/input/datasets/dasandco/clindataset/train/25f0621dae8874aac9985c4034a565ea.png
# /kaggle/input/datasets/dasandco/clindataset/train/892e41c7ed24db564a46d384de10c99c.png
# /kaggle/input/datasets/dasandco/clindataset/train/a3d5137d2817fa1a7497352d16b31b20.png
# /kaggle/input/datasets/dasandco/clindataset/train/639204be22db7a0e9c9502a44a1c9fe8.png
# /kaggle/input/datasets/dasandco/clindataset/train/8a72ffa869927722e05660e3c0f79477.png
# /kaggle/input/datasets/dasandco/clindataset/train/b1e62ea9569c1bf8988e5c09cf72cc57.png
# /kaggle/input/datasets/dasandco/clindataset/train/4d8fb15d5bf045d6fb3809b305ce9d42.png
# /kaggle/input/datasets/dasandco/clindataset/train/ed22220de1dad24c60f4fe28dedbff6d.png
# /kaggle/input/datasets/dasandco/clindataset/train/b5a3de338d33d96e3bfa129f7a4172ca.png
# /kaggle/input/datasets/dasandco/clindataset/train/62deaf5f6e7d93b940f8dcdec0b6c121.png
# /kaggle/input/datasets/dasandco/clindataset/train/e1e74a1b970197d2b8a236f4ddd8f3d5.png
# /kaggle/input/datasets/dasandco/clindataset/train/e76af44f2856bf89d69d00d43536cf8c.png
# /kaggle/input/datasets/dasandco/clindataset/train/1981a0c4cdbb5d4eeb9c2572813a453f.png
# /kaggle/input/datasets/dasandco/clindataset/train/a7911c0364a00437dc27f8db4b95980f.png
# /kaggle/input/datasets/dasandco/clindataset/train/887361080ccbd381147d15c8da41eca4.png
# /kaggle/input/datasets/dasandco/clindataset/train/50d3bca9ce9188a7ca8bed24a99b3c02.png
# /kaggle/input/datasets/dasandco/clindataset/train/14a35e1f083bd63954592ce015771d0b.png
# /kaggle/input/datasets/dasandco/clindataset/train/565f761092a0cbc6f85c8195de091343.png
# /kaggle/input/datasets/dasandco/clindataset/train/19514c760278af2a9c30c1a066ca5a34.png
# /kaggle/input/datasets/dasandco/clindataset/train/35587a8b8b325a6f2179d33bd26aa0fe.png
# /kaggle/input/datasets/dasandco/clindataset/train/ef85cda3a115da5e7399342ac986d489.png
# /kaggle/input/datasets/dasandco/clindataset/train/641968ae3a4233add5aac188531b6727.png
# /kaggle/input/datasets/dasandco/clindataset/train/4d367c0fdb57acae2ddd9c892ed2d135.png
# /kaggle/input/datasets/dasandco/clindataset/train/22807ea675967a02baf8f510543a4a95.png
# /kaggle/input/datasets/dasandco/clindataset/train/3271043bd7d7dcca640a3f1909f7eae4.png
# /kaggle/input/datasets/dasandco/clindataset/train/70b916c56dbe91ca3903bd5ecd48cce6.png
# /kaggle/input/datasets/dasandco/clindataset/train/b3c00be8bb1e193775433d45ead67f95.png
# /kaggle/input/datasets/dasandco/clindataset/train/76992cdbd67daee6673e6b9b5234748c.png
# /kaggle/input/datasets/dasandco/clindataset/train/f0cfa6052ecd8c00881f71de6bdd91ae.png
# /kaggle/input/datasets/dasandco/clindataset/train/3c7400e326b4c475d22b21e84ac64b87.png
# /kaggle/input/datasets/dasandco/clindataset/train/ecbacb5e591dfa3ed48c414221c813c7.png
# /kaggle/input/datasets/dasandco/clindataset/train/495d95ba28ef8dbbc1b85dca9c94ed67.png
# /kaggle/input/datasets/dasandco/clindataset/train/98dca7e62a4f2d47455b9a275fa75a08.png
# /kaggle/input/datasets/dasandco/clindataset/train/02de1ec3340e75fd5e7294a84a0342a1.png
# /kaggle/input/datasets/dasandco/clindataset/train/4e626c17759ec3e794d6636fba71d128.png
# /kaggle/input/datasets/dasandco/clindataset/train/64fd33bb2dbe5f2c9d376a66820b4014.png
# /kaggle/input/datasets/dasandco/clindataset/train/b948592be9abd5dcf1a570c72887c033.png
# /kaggle/input/datasets/dasandco/clindataset/train/3ae48108f30488aee672f1dab2bea20f.png
# /kaggle/input/datasets/dasandco/clindataset/train/6bdd54328b0a11fbd13ad9ae633a82d0.png
# /kaggle/input/datasets/dasandco/clindataset/train/bf3d0f4f27c93aa8cd88e57010b490da.png
# /kaggle/input/datasets/dasandco/clindataset/train/8900e436ef9c73811c793b32127de1b8.png
# /kaggle/input/datasets/dasandco/clindataset/train/b192b0ddffed39cf6894a6beab870f9e.png
# /kaggle/input/datasets/dasandco/clindataset/train/92c23fda0d7ea33fa3e9aab418ee446f.png
# /kaggle/input/datasets/dasandco/clindataset/train/c1c9528727dd016bad131ff8c3863774.png
# /kaggle/input/datasets/dasandco/clindataset/train/4222442e8764f5246f29f9974292599d.png
# /kaggle/input/datasets/dasandco/clindataset/train/f4c12a07224893104dec25b926db33a1.png
# /kaggle/input/datasets/dasandco/clindataset/train/edb67efb2fbf3647dbf9c4daec79da3f.png
# /kaggle/input/datasets/dasandco/clindataset/train/f680bcf8c99e7817749be9abfbf3000b.png
# /kaggle/input/datasets/dasandco/clindataset/train/45df4dae1e6f49f649ebc1aacb8d755b.png
# /kaggle/input/datasets/dasandco/clindataset/train/0452d38f45e4e79f91821e88bb812608.png
# /kaggle/input/datasets/dasandco/clindataset/train/938d2fcf6e65f8b9f1489dd8ceab7ca8.png
# /kaggle/input/datasets/dasandco/clindataset/train/94219113f84fc484f643867c6a11c742.png
# /kaggle/input/datasets/dasandco/clindataset/train/b57763fed61d020d0338a35dd06a4011.png
# /kaggle/input/datasets/dasandco/clindataset/train/9d839a52c0fc61167a2f95ae6f7ee5ad.png
# /kaggle/input/datasets/dasandco/clindataset/train/f986361b73fb2d464ae4c550d8e95529.png
# /kaggle/input/datasets/dasandco/clindataset/train/486c8b33f33a2c401fd09f2eda3fb9b8.png
# /kaggle/input/datasets/dasandco/clindataset/train/05154c0bdf203a2bd583d95532d0297d.png
# /kaggle/input/datasets/dasandco/clindataset/train/fa1ffc0e890d0d6fa472f8abb1590b88.png
# /kaggle/input/datasets/dasandco/clindataset/train/8f4c737a0dbc8fc4be1e1def59ef4fa9.png
# /kaggle/input/datasets/dasandco/clindataset/train/e0f950fd8305e0be7090868f30906594.png
# /kaggle/input/datasets/dasandco/clindataset/train/19a8657db54ba2c4b22dc25bb33cc113.png
# /kaggle/input/datasets/dasandco/clindataset/train/00c726dca086fc483d639dd5f1ca48c0.png
# /kaggle/input/datasets/dasandco/clindataset/train/b386161449cca3a4cae69f0fd726c02a.png
# /kaggle/input/datasets/dasandco/clindataset/train/a5ae36dfad78f8734605d73781b02f3b.png
# /kaggle/input/datasets/dasandco/clindataset/train/3cc73c9398bff1f052f860c9d5f6ca90.png
# /kaggle/input/datasets/dasandco/clindataset/train/3c0908f1c50c600d8a68f4b4a093b6ce.png
# /kaggle/input/datasets/dasandco/clindataset/train/18b362567e282e3ada32ee486ea6bad1.png
# /kaggle/input/datasets/dasandco/clindataset/train/1e58fd00852763634630540c1d09621d.png
# /kaggle/input/datasets/dasandco/clindataset/train/5e86b52242e527ea2eaca51fdb1d9012.png
# /kaggle/input/datasets/dasandco/clindataset/train/323529ba8352295b65b4ee9380abc1b5.png
# /kaggle/input/datasets/dasandco/clindataset/train/8f752093ee546364e7a3f570c7e2041d.png
# /kaggle/input/datasets/dasandco/clindataset/train/2d533bf631b2b5899008a3a8f6f44a7a.png
# /kaggle/input/datasets/dasandco/clindataset/train/03ec9ca738f579b956cb4af13efa155a.png
# /kaggle/input/datasets/dasandco/clindataset/train/3b37f8d28d0153cedc41acb8020a0a6f.png
# /kaggle/input/datasets/dasandco/clindataset/train/92cc2be1500427075fed66385ea7dc97.png
# /kaggle/input/datasets/dasandco/clindataset/train/728ab8bd828b09fc9ef588de31e88d4d.png

# %%
# !pip install torch torchvision timm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (1.0.24)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm) (1.4.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm) (0.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm) (0.16.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface_hub->timm) (8.3.1)

# %%
import os
import pandas as pd
import numpy as np
from PIL import Image
from tqdm import tqdm

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models

# %%
train_csv = "/kaggle/input/datasets/dasandco/clindataset/train.csv"
img_dir = "/kaggle/input/datasets/dasandco/clindataset/train"
df = pd.read_csv(train_csv)

# %% [markdown]
# # Remove "No Finding"

# %%
df = df[df["class_id"] != 14]

# %%
# Create Image  Single Label Mapping
df = df.sort_values("image_id")

df_single = df.groupby("image_id").first().reset_index()

print("Total images:", len(df_single))
# Out:
# Total images: 4394

# %%
class XrayDataset(Dataset):
    def __init__(self, df, img_dir, transform=None):
        self.df = df
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        
        img_path = os.path.join(self.img_dir, row["image_id"] + ".png")
        image = Image.open(img_path).convert("RGB")
        
        label = int(row["class_id"])
        
        if self.transform:
            image = self.transform(image)
        
        return image, label

# %%
#Transforms
transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
])

# %% [markdown]
# # Create Dataset + Loader

# %%
dataset = XrayDataset(df_single, img_dir, transform)

train_loader = DataLoader(dataset, batch_size=16, shuffle=True)

# %% [markdown]
# # Load Model (ResNet50)

# %%
model = models.resnet50(pretrained=True)

model.fc = nn.Linear(model.fc.in_features, 14)

model = model.cuda()
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 214MB/s]

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
epochs = 5

for epoch in range(epochs):
    
    model.train()
    total_loss = 0
    
    for images, labels in train_loader:
        
        images = images.cuda()
        labels = labels.cuda()
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    
    print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")
# Out:
# Epoch 1, Loss: 562.3804
# Epoch 2, Loss: 495.7861
# Epoch 3, Loss: 427.4897
# Epoch 4, Loss: 293.0826
# Epoch 5, Loss: 134.9698

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
import torch.nn.functional as F

# %%
model.eval()

all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    
    for images, labels in train_loader:
        
        images = images.cuda()
        labels = labels.cuda()
        
        outputs = model(images)
        
        probs = F.softmax(outputs, dim=1)
        preds = torch.argmax(probs, dim=1)
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

# %%
accuracy = accuracy_score(all_labels, all_preds)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9301319981793355

# %%
f1 = f1_score(all_labels, all_preds, average='macro')
print("F1 Score:", f1)
# Out:
# F1 Score: 0.8346002606567324

# %%
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
print("AUC:", auc)
# Out:
# AUC: 0.9976688402900283

# %%
torch.save(model.state_dict(), "/kaggle/working/cliniscan_classification_model.pth")

print("Model saved successfully")
# Out:
# Model saved successfully

# %%
import os

print(os.listdir("/kaggle/working"))
# Out:
# ['cliniscan_classification_model.pth', '__notebook__.ipynb']

# %%
from IPython.display import FileLink

FileLink("/kaggle/working/cliniscan_classification_model.pth")
# Out:
# /kaggle/working/cliniscan_classification_model.pth

# %%
class_names = {
 0: "Aortic enlargement",
 1: "Atelectasis",
 2: "Calcification",
 3: "Cardiomegaly",
 4: "Consolidation",
 5: "ILD",
 6: "Infiltration",
 7: "Lung Opacity",
 8: "Nodule/Mass",
 9: "Other lesion",
 10: "Pleural effusion",
 11: "Pleural thickening",
 12: "Pneumothorax",
 13: "Pulmonary fibrosis"
}

import json

with open("/kaggle/working/class_names.json", "w") as f:
    json.dump(class_names, f)

# %%
FileLink("/kaggle/working/class_names.json")
# Out:
# /kaggle/working/class_names.json
